# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanzeynal/TensorFlow-Developer-Certificate/blob/main/Exercises/02_neural_network_classification_in_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score,f1_score,recall_score, precision_score

# %% [markdown]
# # Exercise 1:
# Create a classification dataset using Scikit-Learn's make_moons() function, visualize it and then build a model to fit it at over 85% accuracy.

# %%
#import make_moons() from sklearn
from sklearn.datasets import make_moons

X,y = make_moons(n_samples=1000,
                 random_state= 42)

#create dataframe
make_moons_df = pd.DataFrame({'X_1': X[:,0],
                              'X_2': X[:,1],
                              'Y': y})

#print make_moons_df
make_moons_df.head()
# Out:
#         X_1       X_2  Y
# 0  0.008727  0.368174  1
# 1  0.921384 -0.496905  1
# 2  0.940226 -0.498212  1
# 3  0.465875 -0.345406  1
# 4 -0.850412  0.526117  0

# %%
#plot the dataframe visualization
plt.figure(figsize=(12,7))
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
#let's try creating a model with over 85% accuracy

#create the subsets for X and y
X_train= X[:800]
X_test= X[800:]
y_train= y[:800]
y_test= y[800:]

#set the random seed
tf.random.set_seed(42)

#create the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, activation= 'relu'),
    tf.keras.layers.Dense(100, activation= 'relu'),
    tf.keras.layers.Dense(1, activation= 'sigmoid')
])

#compile the model
model.compile(loss= tf.keras.losses.binary_crossentropy,
              optimizer = tf.keras.optimizers.Adam(),
              metrics= ['accuracy'])

#set the callback(lr_scheduler which means LearningRateSchduler)
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * 10 **(epoch/20))

#fit the model
history = model.fit(X_train, y_train, epochs= 30,
          callbacks=[lr_scheduler],
          validation_data= (X_test,y_test))
# Out:
# Epoch 1/30
# 25/25 [==============================] - 2s 11ms/step - loss: 0.5528 - accuracy: 0.8087 - val_loss: 0.4482 - val_accuracy: 0.8050 - lr: 0.0010
# Epoch 2/30
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3518 - accuracy: 0.8575 - val_loss: 0.3106 - val_accuracy: 0.8300 - lr: 0.0011
# Epoch 3/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.8813 - val_loss: 0.2631 - val_accuracy: 0.8500 - lr: 0.0013
# Epoch 4/30
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2265 - accuracy: 0.8900 - val_loss: 0.2406 - val_accuracy: 0.8950 - lr: 0.0014
# Epoch 5/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1990 - accuracy: 0.9025 - val_loss: 0.2011 - val_accuracy: 0.9000 - lr: 0.0016
# Epoch 6/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1725 - accuracy: 0.9050 - val_loss: 0.1749 - val_accuracy: 0.9200 - lr: 0.0018
# Epoch 7/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9388 - val_loss: 0.1310 - val_accuracy: 0.9400 - lr: 0.0020
# Epoch 8/30
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1009 - accuracy: 0.9625 - val_loss: 0.0831 - val_accuracy: 0.9750 - lr: 0.0022
# Epoch 9/30
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0680 - accuracy: 0.9787 - val_loss: 0.0496 - val_accuracy: 0.9900 - lr: 0.0025
# Epoch 10/30
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0334 - accuracy: 0.9962 - val_loss: 0.0242 - val_accuracy: 1.0000 - lr: 0.0028
# Epoch 11/30
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000 - lr: 0.0032
# Epoch 12/30
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - lr: 0.0035
# Epoch 13/30
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000 - lr: 0.0040
# Epoch 14/30
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - lr: 0.0045
# Epoch 15/30
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 0.0050
# Epoch 16/30
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 8.4155e-04 - val_accuracy: 1.0000 - lr: 0.0056
# Epoch 17/30
# 25/25 [==============================] - 0s 13ms/step - loss: 5.8822e-04 - accuracy: 1.0000 - val_loss: 5.1793e-04 - val_accuracy: 1.0000 - lr: 0.0063
# Epoch 18/30
# 25/25 [==============================] - 0s 18ms/step - loss: 3.5214e-04 - accuracy: 1.0000 - val_loss: 3.3096e-04 - val_accuracy: 1.0000 - lr: 0.0071
# Epoch 19/30
# 25/25 [==============================] - 0s 17ms/step - loss: 2.3321e-04 - accuracy: 1.0000 - val_loss: 2.1325e-04 - val_accuracy: 1.0000 - lr: 0.0079
# Epoch 20/30
# 25/25 [==============================] - 0s 8ms/step - loss: 1.6268e-04 - accuracy: 1.0000 - val_loss: 1.5112e-04 - val_accuracy: 1.0000 - lr: 0.0089
# Epoch 21/30
# 25/25 [==============================] - 0s 8ms/step - loss: 1.1390e-04 - accuracy: 1.0000 - val_loss: 1.1289e-04 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 22/30
# 25/25 [==============================] - 0s 8ms/step - loss: 8.7195e-05 - accuracy: 1.0000 - val_loss: 8.5601e-05 - val_accuracy: 1.0000 - lr: 0.0112
# Epoch 23/30
# 25/25 [==============================] - 0s 11ms/step - loss: 6.6252e-05 - accuracy: 1.0000 - val_loss: 6.8736e-05 - val_accuracy: 1.0000 - lr: 0.0126
# Epoch 24/30
# 25/25 [==============================] - 0s 9ms/step - loss: 5.3099e-05 - accuracy: 1.0000 - val_loss: 5.3586e-05 - val_accuracy: 1.0000 - lr: 0.0141
# Epoch 25/30
# 25/25 [==============================] - 0s 5ms/step - loss: 4.2920e-05 - accuracy: 1.0000 - val_loss: 4.2410e-05 - val_accuracy: 1.0000 - lr: 0.0158
# Epoch 26/30
# 25/25 [==============================] - 0s 9ms/step - loss: 3.4275e-05 - accuracy: 1.0000 - val_loss: 3.4999e-05 - val_accuracy: 1.0000 - lr: 0.0178
# Epoch 27/30
# 25/25 [==============================] - 0s 12ms/step - loss: 2.8006e-05 - accuracy: 1.0000 - val_loss: 2.8543e-05 - val_accuracy: 1.0000 - lr: 0.0200
# Epoch 28/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.2709e-05 - accuracy: 1.0000 - val_loss: 2.3761e-05 - val_accuracy: 1.0000 - lr: 0.0224
# Epoch 29/30
# 25/25 [==============================] - 0s 6ms/step - loss: 1.8917e-05 - accuracy: 1.0000 - val_loss: 1.9460e-05 - val_accuracy: 1.0000 - lr: 0.0251
# Epoch 30/30
# 25/25 [==============================] - 0s 6ms/step - loss: 1.5666e-05 - accuracy: 1.0000 - val_loss: 1.6303e-05 - val_accuracy: 1.0000 - lr: 0.0282

# %%
#make the dataframe for lr's,losses,accuracy and etc.
pd.DataFrame(history.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   0.552769   0.80875  0.448214         0.805  0.001000
# 1   0.351779   0.85750  0.310613         0.830  0.001122
# 2   0.262787   0.88125  0.263103         0.850  0.001259
# 3   0.226481   0.89000  0.240595         0.895  0.001413
# 4   0.198984   0.90250  0.201056         0.900  0.001585
# 5   0.172509   0.90500  0.174887         0.920  0.001778
# 6   0.144347   0.93875  0.130951         0.940  0.001995
# 7   0.100853   0.96250  0.083051         0.975  0.002239
# 8   0.067968   0.97875  0.049602         0.990  0.002512
# 9   0.033352   0.99625  0.024200         1.000  0.002818
# 10  0.016232   1.00000  0.013104         1.000  0.003162
# 11  0.007857   1.00000  0.006777         1.000  0.003548
# 12  0.004727   1.00000  0.003859         1.000  0.003981
# 13  0.002729   1.00000  0.002399         1.000  0.004467
# 14  0.001701   1.00000  0.001434         1.000  0.005012
# 15  0.001015   1.00000  0.000842         1.000  0.005623
# 16  0.000588   1.00000  0.000518         1.000  0.006310
# 17  0.000352   1.00000  0.000331         1.000  0.007079
# 18  0.000233   1.00000  0.000213         1.000  0.007943
# 19  0.000163   1.00000  0.000151         1.000  0.008913
# 20  0.000114   1.00000  0.000113         1.000  0.010000
# 21  0.000087   1.00000  0.000086         1.000  0.011220
# 22  0.000066   1.00000  0.000069         1.000  0.012589
# 23  0.000053   1.00000  0.000054         1.000  0.014125
# 24  0.000043   1.00000  0.000042         1.000  0.015849
# 25  0.000034   1.00000  0.000035         1.000  0.017783
# 26  0.000028   1.00000  0.000029         1.000  0.019953
# 27  0.000023   1.00000  0.000024         1.000  0.022387
# 28  0.000019   1.00000  0.000019         1.000  0.025119
# 29  0.000016   1.00000  0.000016         1.000  0.028184

# %%
#visualize the metrics ald lr rates
plt.figure(figsize=(16,9))
pd.DataFrame(history.history).plot()
plt.show()

# %%
#make the plot between loss and learning rates

#learning rates
lrs = 0.001 * 10 **(tf.range(30)/20)

#make the plot
plt.figure(figsize=(16,9))
plt.semilogx(lrs,pd.DataFrame(history.history)['loss'])
#set the xlabel and ylabel,title
plt.title('Learning Rates vs Losses')
plt.xlabel('Learning Rates')
plt.ylabel('Losses')
#show the plot
plt.show()

# %% [markdown]
# # Exercise 2:
# Create a function (or write code) to visualize multiple image predictions for the fashion MNIST at the same time. Plot at least three different images and their prediciton labels at the same time.
# * **Hint:** see the classifcation tutorial in the TensorFlow documentation for ideas.

# %%
#import fashionmnist datasets
from tensorflow.keras.datasets import fashion_mnist
(train_images,train_labels),(test_images,test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
#the shapes of train and test sets
train_images.shape, test_images.shape, train_labels.shape, test_labels.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
#make the list that has to consist of names of clothes
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(12,7))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap= plt.cm.binary)
  plt.xlabel(class_names[test_labels[i]])
plt.show()

# %%
#normilize data
norm_train_images= train_images / 255
norm_test_images= test_images / 255

#set the random seed
tf.random.set_seed(42)

#create the model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(100, activation= 'relu'),
    tf.keras.layers.Dense(100, activation= 'relu'),
    tf.keras.layers.Dense(10, activation= 'softmax')
])

#compile the model
model_1.compile(loss= tf.keras.losses.CategoricalCrossentropy(),
                optimizer= tf.keras.optimizers.Adam(lr= 0.01),
                metrics= 'accuracy')

#fit the model
model_1_history = model_1.fit(norm_train_images, tf.one_hot(train_labels, depth= 10), epochs= 20, validation_data= (norm_test_images,tf.one_hot(test_labels, depth= 10)))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4965 - accuracy: 0.8223 - val_loss: 0.4207 - val_accuracy: 0.8447
# Epoch 2/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3674 - accuracy: 0.8654 - val_loss: 0.4452 - val_accuracy: 0.8442
# Epoch 3/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3333 - accuracy: 0.8762 - val_loss: 0.3803 - val_accuracy: 0.8613
# Epoch 4/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3102 - accuracy: 0.8853 - val_loss: 0.3665 - val_accuracy: 0.8674
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2929 - accuracy: 0.8902 - val_loss: 0.3581 - val_accuracy: 0.8711
# Epoch 6/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2772 - accuracy: 0.8944 - val_loss: 0.3608 - val_accuracy: 0.8643
# Epoch 7/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2667 - accuracy: 0.9000 - val_loss: 0.3842 - val_accuracy: 0.8586
# Epoch 8/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2539 - accuracy: 0.9036 - val_loss: 0.3358 - val_accuracy: 0.8833
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2442 - accuracy: 0.9089 - val_loss: 0.3332 - val_accuracy: 0.8809
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2372 - accuracy: 0.9108 - val_loss: 0.3300 - val_accuracy: 0.8823
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2268 - accuracy: 0.9141 - val_loss: 0.3236 - val_accuracy: 0.8907
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2203 - accuracy: 0.9172 - val_loss: 0.3380 - val_accuracy: 0.8876
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2149 - accuracy: 0.9188 - val_loss: 0.3430 - val_accuracy: 0.8828
# Epoch 14/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2074 - accuracy: 0.9209 - val_loss: 0.3367 - val_accuracy: 0.8889
# Epoch 15/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2003 - accuracy: 0.9240 - val_loss: 0.3564 - val_accuracy: 0.8813
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1946 - accuracy: 0.9272 - val_loss: 0.3555 - val_accuracy: 0.8805
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1906 - accuracy: 0.9273 - val_loss: 0.3468 - val_accuracy: 0.8877
# Epoch 18/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1863 - accuracy: 0.9295 - val_loss: 0.3405 - val_accuracy: 0.8921
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1808 - accuracy: 0.9312 - val_loss: 0.3679 - val_accuracy: 0.8822
# Epoch 20/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1761 - accuracy: 0.9325 - val_loss: 0.3695 - val_accuracy: 0.8894

# %%
#make the probability model
# proba_model = tf.keras.models.Sequential([
#     model_1,
#     tf.keras.layers.Softmax()
# ])
y_proba = model_1.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
#show the predictions as a visualize
plt.figure(figsize=(16,9))
plt.title('Predictions')
for i in range(25):
  plt.subplot(5, 5, i + 1)
  plt.xticks([])
  plt.yticks([])

  if np.argmax(y_proba[i]) == test_labels[i]:
    color = 'g'
  else:
    color = 'r'
  plt.imshow(test_images[i], cmap= plt.cm.binary)
  plt.xlabel("{} {}%({})".format(class_names[np.argmax(y_proba[i])],
                                 np.round(100* y_proba[i].max(),0),
                                  class_names[test_labels[i]]),
                                  color= color)
plt.show()
# Out:
# <ipython-input-109-3489c77842e5>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5, 5, i + 1)

# %% [markdown]
# #Exercise 3:
# Recreate TensorFlow's softmax activation function in your own code. Make sure it can accept a tensor and return that tensor after having the softmax function applied to it.

# %% [markdown]
# **The softmax function** is a function that turns a vector of K real values into a vector of K real values that sum to 1. The input values can be positive, negative, zero, or greater than one, but the softmax transforms them into values between 0 and 1, so that they can be interpreted as probabilities.

# %% [markdown]
# ![pasted image 0.png](data:image/png;base64,...)

# %%
#creating softmax function from scratch
def softmax(x):
  x = tf.cast(x , dtype = tf.float32) # to tackle the data type error of int32 / int64

  # Below is the forumale
  e_x = tf.math.exp(x - tf.math.reduce_max(x))
  return e_x / tf.math.reduce_sum(e_x , axis = 0)

# %%
#get the tensor sample
tensor_1 = [[1, 2, 3, 6],
            [2, 4, 5, 6],
            [3, 8, 7, 6]]

# %%
#returns softmax of our tensor_1
softmax(tensor_1)
# Out:
# <tf.Tensor: shape=(3, 4), dtype=float32, numpy=
# array([[0.09003057, 0.00242826, 0.01587624, 0.3333333 ],
#        [0.24472849, 0.01794253, 0.11731041, 0.3333333 ],
#        [0.66524094, 0.9796292 , 0.8668133 , 0.3333333 ]], dtype=float32)>

# %% [markdown]
# # Exercise 4:
# Train a model to get 88%+ accuracy on the fashion MNIST test set. Plot a confusion matrix to see the results after.
# * 88% is done.
# * As a second exercise, let's get confusion matrix

# %%
predictions = []
for i in range(10000):
  predictions.append(y_proba[i].argmax())
predictions[:10]
# Out:
# [9, 2, 1, 1, 0, 1, 4, 6, 5, 7]

# %%
plt.figure(figsize=(16,9))
#get the confusion matrix
cm = confusion_matrix(test_labels,predictions)
#plot the confusion matrix as a visualize
sns.heatmap(cm, annot=True, xticklabels=class_names, yticklabels= class_names, cmap= plt.cm.Greys)
#set the title
plt.title('Confusion Matrix as a Visualize')
#set the x and y label
# plt.xlabel(class_names)
# plt.ylabel(class_names)
#show the plot
plt.show()

# %% [markdown]
# # Exercise 5:
#  Make a function to show an image of a certain class of the fashion MNIST dataset and make a prediction on it. For example, plot 3 images of the T-shirt class with their predictions.

# %%
class_names,predictions[:10]
# Out:
# (['T-shirt/top',
#   'Trouser',
#   'Pullover',
#   'Dress',
#   'Coat',
#   'Sandal',
#   'Shirt',
#   'Sneaker',
#   'Bag',
#   'Ankle boot'],
#  [9, 2, 1, 1, 0, 1, 4, 6, 5, 7])

# %%
plt.imshow(train_images[0])

# %%
predictions[25] , test_labels[25]
# Out:
# (4, 4)

# %%
#plot the 6 images of T-shirt/top with their prediction s
plt.figure(figsize=(16,9))
for i in range(10000):
  for j in range(6):
    if predictions[i] == 0:
      plt.subplot(2, 3, j + 1)
      plt.xticks([])
      plt.yticks([])
      #set the color
      if predictions[i] == test_labels[i]:
        color = 'g'
      else:
        color = 'r'
        plt.imshow(test_images[i], cmap= plt.cm.Greys)
        #set the xlabel as true label, accuracy, predicted
        plt.xlabel('T-shirt/top {}%({})'.format(np.round(100*y_proba[i].max(),0),
                                              class_names[predictions[i]]),
                                                color=color)
#show the title
plt.show()
